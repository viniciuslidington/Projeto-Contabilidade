# %% [markdown]
# # Preparando df

# %%
import pandas as pd
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# !pip install odfpy==1.4.1
# Out:
# Requirement already satisfied: odfpy==1.4.1 in /usr/local/lib/python3.11/dist-packages (1.4.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from odfpy==1.4.1) (0.7.1)

# %%
path = "/content/CC&Gerencial_Base de Dados (Atividade 2º Exercício).ods"
df = pd.read_excel(path)

# %%
df.head()
# Out:
#    Filial Orig       Data Banco  Agencia  Conta Banco    Natureza  \
# 0      10101.0 2023-01-02   077      1.0  173862322.0  11202003.0
# 1      10101.0 2023-01-04   077      1.0  173862322.0  11202003.0
# 2      10101.0 2023-01-05   077      1.0  173862322.0  11101001.0
# 3      10101.0 2023-01-05   077      1.0  173862322.0  21105007.0
# 4      10101.0 2023-01-05   077      1.0  173862322.0  21101002.0
#
#                     Nome Natureza     Documento  Entrada   Saida  \
# 0        ADIANTAMENTO DE CLIENTES  ADT-02012023   1600.0     NaN
# 1        ADIANTAMENTO DE CLIENTES  ADT-04012023   2300.0     NaN
# 2                MARKETING DIRETO      1-000218   1450.0     NaN
# 3  ADIANT. DE LUCRO - MATEUS MACI  ADT-05012023      NaN    50.0
# 4                     CONSULTORIA        001123      NaN  1450.0
#
#                      Historico
# 0          ADT RF NF 231 FIRST
# 1  ADT RF NF 226 GERACAO ATUAL
# 2   RECBT RF NF 218 RR MARCO Z
# 3             ADT MATEUS LEITE
# 4         PGTO RF NF 1123 MUST

# %%
df['Data'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
df['Data'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Mes_Ano'] = df['Data'].dt.to_period('M')

# %%
df.head(10)
# Out:
#    Filial Orig       Data Banco  Agencia  Conta Banco    Natureza  \
# 0      10101.0 2023-01-02   077      1.0  173862322.0  11202003.0
# 1      10101.0 2023-01-04   077      1.0  173862322.0  11202003.0
# 2      10101.0 2023-01-05   077      1.0  173862322.0  11101001.0
# 3      10101.0 2023-01-05   077      1.0  173862322.0  21105007.0
# 4      10101.0 2023-01-05   077      1.0  173862322.0  21101002.0
# 5      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 6      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 7      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 8      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 9      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
#
#                     Nome Natureza     Documento  Entrada   Saida  \
# 0        ADIANTAMENTO DE CLIENTES  ADT-02012023   1600.0     NaN
# 1        ADIANTAMENTO DE CLIENTES  ADT-04012023   2300.0     NaN
# 2                MARKETING DIRETO      1-000218   1450.0     NaN
# 3  ADIANT. DE LUCRO - MATEUS MACI  ADT-05012023      NaN    50.0
# 4                     CONSULTORIA        001123      NaN  1450.0
# 5  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2213.6
# 6  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2485.2
# 7  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  1972.2
# 8  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  1272.2
# 9  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2357.2
#
#                      Historico  Mes_Ano
# 0          ADT RF NF 231 FIRST  2023-01
# 1  ADT RF NF 226 GERACAO ATUAL  2023-01
# 2   RECBT RF NF 218 RR MARCO Z  2023-01
# 3             ADT MATEUS LEITE  2023-01
# 4         PGTO RF NF 1123 MUST  2023-01
# 5         ADT RF NF GABRIELA M  2023-01
# 6       ADT RF NF LUCAS AQUINO  2023-01
# 7           ADT RF NF ARYELE B  2023-01
# 8            ADT RF NF LUISE M  2023-01
# 9      ADT RF NF MARIA EDUARDA  2023-01

# %%
# Count rows where both 'Despesas' and 'Saida' are null
null_count = len(df[(df['Saida'].isnull()) & (df['Entrada'].isnull())])

print(f"Number of rows where both 'Despesas' and 'Saida' are null: {null_count}")
# Out:
# Number of rows where both 'Despesas' and 'Saida' are null: 1

# %%
df.dropna(subset=['Entrada', 'Saida'], how='all', inplace=True)

# %%
null_count = len(df[(df['Saida'].isnull()) & (df['Entrada'].isnull())])

print(f"Number of rows where both 'Despesas' and 'Saida' are null: {null_count}")
# Out:
# Number of rows where both 'Despesas' and 'Saida' are null: 0

# %%
df['Nome Natureza'].value_counts()
# Out:
# Nome Natureza
# SERVICOS DE PUBLICIDADE E PROP    439
# ADIANTAMENTO DE CLIENTES          410
# ADIANT. DE LUCRO - CARLOS HENR    381
# MARKETING DIRETO                  255
# APLICACAO ITAU AUTO MAIS          210
# RESGATE ITAU AUTO MAIS            190
# TARIFAS BANCARIAS                 162
# ADIANT. DE LUCRO - MATEUS MACI    129
# ADIANT. DE LUCRO - MANOEL VIRG     65
# TELEFONIA  MOVEL                   47
# RECEITA DE JUROS                   42
# RENDIMENTO DE APLICACOES FINAN     37
# SIMPLES NACIONAL                   34
# RESGATE INTER CDB MAIS             28
# PRO LABORE                         27
# IOF                                26
# ENERGIA ELETRICA                   25
# CONSULTORIA                        25
# PAGAMENTOS DIVERSOS                24
# INSS SOBRE PRO LABORE              22
# LICENCA DE USO                     21
# ENTRADAS DE TRANSFERENCIAS         18
# CONDOMINIO                         18
# CONSORCIO ITAU                     14
# ALUGUEL DE IMOVEIS                 14
# AJUSTE DE RENDIMENTO APLICACAO     13
# CONDUCAO E TRANSPORTE              12
# JUROS PAGOS                        10
# APORTES                             9
# IRRF APLICACAO FINANCEIRA           9
# SEGUROS PESSOAIS E EMPRESARIAI      4
# CIM CADASTRO INSCRICAO MUNICIP      4
# OUTRAS DESPESAS                     4
# APLICACAO INTER CDB MAIS            4
# LANCHES E REFEICOES                 3
# IPTU IMP PREDIAL TERRIT URBANO      3
# DOACOES E CONTRIBUICOES             2
# SERVICOS LIMPEZA E CONSERVACAO      2
# SERVICO DE DIVULGACAO               2
# CERTIFICADO DIGITAL                 2
# INDENIZACOES RECEBIDAS              1
# PORTAIS, PROVEDORES DE CONTEÚD      1
# EMOLUMENTOS CARTORIOS               1
# JUROS RECEBIDOS                     1
# CONFRATERNIZACAO                    1
# CURSOS E TREINAMENTOS               1
# TELEFONIA  FIXA                     1
# SERVICOS INFORMATICA                1
# TAXAS MUNICIPAIS                    1
# OUTRAS RECEITAS NAO OPERACIONA      1
# MATERIAL DE EXPEDIENTE              1
# MULTAS PUNITIVAS                    1
# Name: count, dtype: int64

# %%
# Cria a condição booleana
condicao = df['Nome Natureza'].isin([
    "ADIANT. DE LUCRO - CARLOS HENR",
    "ADIANT. DE LUCRO - MATEUS MACI",
    "ADIANT. DE LUCRO - MANOEL VIRG"
])

# Usa loc para acessar e modificar as linhas que atendem à condição
df.loc[condicao, 'Nome Natureza'] = "ADIANT. DE LUCRO"

# %%
df['Nome Natureza'].value_counts()
# Out:
# Nome Natureza
# ADIANT. DE LUCRO                  575
# SERVICOS DE PUBLICIDADE E PROP    439
# ADIANTAMENTO DE CLIENTES          410
# MARKETING DIRETO                  255
# APLICACAO ITAU AUTO MAIS          210
# RESGATE ITAU AUTO MAIS            190
# TARIFAS BANCARIAS                 162
# TELEFONIA  MOVEL                   47
# RECEITA DE JUROS                   42
# RENDIMENTO DE APLICACOES FINAN     37
# SIMPLES NACIONAL                   34
# RESGATE INTER CDB MAIS             28
# PRO LABORE                         27
# IOF                                26
# CONSULTORIA                        25
# ENERGIA ELETRICA                   25
# PAGAMENTOS DIVERSOS                24
# INSS SOBRE PRO LABORE              22
# LICENCA DE USO                     21
# ENTRADAS DE TRANSFERENCIAS         18
# CONDOMINIO                         18
# CONSORCIO ITAU                     14
# ALUGUEL DE IMOVEIS                 14
# AJUSTE DE RENDIMENTO APLICACAO     13
# CONDUCAO E TRANSPORTE              12
# JUROS PAGOS                        10
# APORTES                             9
# IRRF APLICACAO FINANCEIRA           9
# SEGUROS PESSOAIS E EMPRESARIAI      4
# CIM CADASTRO INSCRICAO MUNICIP      4
# OUTRAS DESPESAS                     4
# APLICACAO INTER CDB MAIS            4
# LANCHES E REFEICOES                 3
# IPTU IMP PREDIAL TERRIT URBANO      3
# DOACOES E CONTRIBUICOES             2
# SERVICOS LIMPEZA E CONSERVACAO      2
# SERVICO DE DIVULGACAO               2
# CERTIFICADO DIGITAL                 2
# INDENIZACOES RECEBIDAS              1
# PORTAIS, PROVEDORES DE CONTEÚD      1
# EMOLUMENTOS CARTORIOS               1
# JUROS RECEBIDOS                     1
# CONFRATERNIZACAO                    1
# CURSOS E TREINAMENTOS               1
# TELEFONIA  FIXA                     1
# SERVICOS INFORMATICA                1
# TAXAS MUNICIPAIS                    1
# OUTRAS RECEITAS NAO OPERACIONA      1
# MATERIAL DE EXPEDIENTE              1
# MULTAS PUNITIVAS                    1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (2760, 12)

# %% [markdown]
# # Despesas

# %%
 df_despesas = df[df['Saida'].notnull()].copy()

# %%
df_despesas.shape
# Out:
# (1743, 12)

# %%
df_despesas.drop(df_despesas[df_despesas["Nome Natureza"] == "JUROS RECEBIDOS"].index, inplace=True)

# %%
df_despesas.dropna(subset=["Nome Natureza"], inplace=True)

# %%
df_despesas['Nome Natureza'].value_counts()
# Out:
# Nome Natureza
# ADIANT. DE LUCRO                  519
# SERVICOS DE PUBLICIDADE E PROP    433
# TARIFAS BANCARIAS                 162
# APLICACAO ITAU AUTO MAIS          105
# RESGATE ITAU AUTO MAIS             95
# TELEFONIA  MOVEL                   47
# SIMPLES NACIONAL                   34
# PRO LABORE                         27
# IOF                                26
# CONSULTORIA                        25
# ENERGIA ELETRICA                   25
# PAGAMENTOS DIVERSOS                24
# INSS SOBRE PRO LABORE              22
# LICENCA DE USO                     20
# ADIANTAMENTO DE CLIENTES           19
# CONDOMINIO                         18
# CONSORCIO ITAU                     14
# RESGATE INTER CDB MAIS             14
# ALUGUEL DE IMOVEIS                 14
# CONDUCAO E TRANSPORTE              12
# RENDIMENTO DE APLICACOES FINAN     12
# JUROS PAGOS                        10
# IRRF APLICACAO FINANCEIRA           9
# ENTRADAS DE TRANSFERENCIAS          9
# AJUSTE DE RENDIMENTO APLICACAO      7
# OUTRAS DESPESAS                     4
# SEGUROS PESSOAIS E EMPRESARIAI      4
# CIM CADASTRO INSCRICAO MUNICIP      4
# LANCHES E REFEICOES                 3
# IPTU IMP PREDIAL TERRIT URBANO      3
# DOACOES E CONTRIBUICOES             2
# APLICACAO INTER CDB MAIS            2
# SERVICO DE DIVULGACAO               2
# MARKETING DIRETO                    2
# SERVICOS LIMPEZA E CONSERVACAO      2
# CERTIFICADO DIGITAL                 2
# CURSOS E TREINAMENTOS               1
# EMOLUMENTOS CARTORIOS               1
# CONFRATERNIZACAO                    1
# SERVICOS INFORMATICA                1
# TAXAS MUNICIPAIS                    1
# TELEFONIA  FIXA                     1
# MATERIAL DE EXPEDIENTE              1
# MULTAS PUNITIVAS                    1
# Name: count, dtype: int64

# %%
def categorizar(nome):
    categorias = {
        "Despesas Operacionais": ["SERVICOS DE PUBLICIDADE E PROP", "MARKETING DIRETO", "SERVICO DE DIVULGACAO",
                                   "CONSULTORIA", "LICENCA DE USO", "SERVICOS INFORMATICA", "SERVICOS LIMPEZA E CONSERVACAO",
                                   "CERTIFICADO DIGITAL"],
        "Despesas Administrativas": ["ALUGUEL DE IMOVEIS", "CONDOMINIO", "ENERGIA ELETRICA", "TELEFONIA MOVEL",
                                      "TELEFONIA FIXA", "MATERIAL DE EXPEDIENTE"],
        "Despesas Financeiras e Tributárias": ["TARIFAS BANCARIAS", "IOF", "JUROS PAGOS", "IRRF APLICACAO FINANCEIRA",
                                               "SIMPLES NACIONAL", "EMOLUMENTOS CARTORIOS", "TAXAS MUNICIPAIS",
                                               "CIM CADASTRO INSCRICAO MUNICIP"],
        "Despesas com Pessoal": ["PRO LABORE", "INSS SOBRE PRO LABORE", "CONFRATERNIZACAO", "CURSOS E TREINAMENTOS",
                                  "LANCHES E REFEICOES"],
        "Investimentos e Aplicações": ["APLICACAO ITAU AUTO MAIS", "RESGATE ITAU AUTO MAIS", "RESGATE INTER CDB MAIS",
                                        "APLICACAO INTER CDB MAIS", "AJUSTE DE RENDIMENTO APLICACAO",
                                        "RENDIMENTO DE APLICACOES FINAN", "CONSORCIO ITAU"],
        "Despesas Eventuais e Diversas": ["ADIANT. DE LUCRO", "ADIANTAMENTO DE CLIENTES", "ENTRADAS DE TRANSFERENCIAS",
                                           "PAGAMENTOS DIVERSOS", "OUTRAS DESPESAS", "SEGUROS PESSOAIS E EMPRESARIAI",
                                           "MULTAS PUNITIVAS", "DOACOES E CONTRIBUICOES", "CONDUCAO E TRANSPORTE",
                                           "IPTU IMP PREDIAL TERRIT URBANO"]
    }

    for categoria, itens in categorias.items():
        if nome in itens:
            return categoria
    return "Outros"

# %%
df_despesas.loc[:, "Categoria"] = df_despesas["Nome Natureza"].apply(categorizar)

# %%
df_despesas.head(10)
# Out:
#     Filial Orig       Data Banco  Agencia  Conta Banco    Natureza  \
# 3       10101.0 2023-01-05   077      1.0  173862322.0  21105007.0
# 4       10101.0 2023-01-05   077      1.0  173862322.0  21101002.0
# 5       10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 6       10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 7       10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 8       10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 9       10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 10      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 11      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
# 12      10101.0 2023-01-06   077      1.0  173862322.0  21101013.0
#
#                      Nome Natureza     Documento  Entrada   Saida  \
# 3                 ADIANT. DE LUCRO  ADT-05012023      NaN    50.0
# 4                      CONSULTORIA        001123      NaN  1450.0
# 5   SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2213.6
# 6   SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2485.2
# 7   SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  1972.2
# 8   SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  1272.2
# 9   SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2357.2
# 10  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2357.2
# 11  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2344.4
# 12  SERVICOS DE PUBLICIDADE E PROP  ADT-06012023      NaN  2385.8
#
#                   Historico  Mes_Ano                      Categoria
# 3          ADT MATEUS LEITE  2023-01  Despesas Eventuais e Diversas
# 4      PGTO RF NF 1123 MUST  2023-01          Despesas Operacionais
# 5      ADT RF NF GABRIELA M  2023-01          Despesas Operacionais
# 6    ADT RF NF LUCAS AQUINO  2023-01          Despesas Operacionais
# 7        ADT RF NF ARYELE B  2023-01          Despesas Operacionais
# 8         ADT RF NF LUISE M  2023-01          Despesas Operacionais
# 9   ADT RF NF MARIA EDUARDA  2023-01          Despesas Operacionais
# 10    ADT RF NF DENNIS LIMA  2023-01          Despesas Operacionais
# 11  ADT RF NF MURILO SANTOS  2023-01          Despesas Operacionais
# 12   ADT RF NF FLAVIO GOMES  2023-01          Despesas Operacionais

# %%
df_despesas.groupby(['Categoria'])['Saida'].sum().reset_index()
# Out:
#                             Categoria      Saida
# 0            Despesas Administrativas   41663.73
# 1       Despesas Eventuais e Diversas  685349.32
# 2  Despesas Financeiras e Tributárias  134119.83
# 3               Despesas Operacionais  593270.94
# 4                Despesas com Pessoal  102260.06
# 5          Investimentos e Aplicações  536370.77
# 6                              Outros   12245.23

# %%
df_despesas['Categoria'].value_counts()
# Out:
# Categoria
# Despesas Eventuais e Diversas         597
# Despesas Operacionais                 487
# Investimentos e Aplicações            249
# Despesas Financeiras e Tributárias    247
# Despesas Administrativas               58
# Despesas com Pessoal                   54
# Outros                                 48
# Name: count, dtype: int64

# %%
df_despesas[df_despesas['Categoria'] == 'Outros']['Nome Natureza'].value_counts()
# Out:
# Nome Natureza
# TELEFONIA  MOVEL    47
# TELEFONIA  FIXA      1
# Name: count, dtype: int64

# %%
df_despesas.loc[df_despesas["Categoria"] == "Outros", "Categoria"] = "Despesas Administrativas"

# %%
df_despesas['Categoria'].value_counts()
# Out:
# Categoria
# Despesas Eventuais e Diversas         597
# Despesas Operacionais                 487
# Investimentos e Aplicações            249
# Despesas Financeiras e Tributárias    247
# Despesas Administrativas              106
# Despesas com Pessoal                   54
# Name: count, dtype: int64

# %%
df_despesas.groupby('Categoria')['Saida'].sum().reset_index()
# Out:
#                             Categoria      Saida
# 0            Despesas Administrativas   53908.96
# 1       Despesas Eventuais e Diversas  685349.32
# 2  Despesas Financeiras e Tributárias  134119.83
# 3               Despesas Operacionais  593270.94
# 4                Despesas com Pessoal  102260.06
# 5          Investimentos e Aplicações  536370.77

# %%
df_despesas[df_despesas["Mes_Ano"] == "2023-01"].groupby("Categoria")["Saida"].sum().reset_index()
# Out:
#                        Categoria     Saida
# 0       Despesas Administrativas   1310.63
# 1  Despesas Eventuais e Diversas  12583.49
# 2          Despesas Operacionais  18837.80
# 3           Despesas com Pessoal   7112.34

# %%
df_despesas[df_despesas["Mes_Ano"] == "2023-02"].groupby("Categoria")["Saida"].sum().reset_index()
# Out:
#                             Categoria     Saida
# 0            Despesas Administrativas   3000.21
# 1       Despesas Eventuais e Diversas  26376.36
# 2  Despesas Financeiras e Tributárias   1863.64
# 3               Despesas Operacionais  21732.86
# 4                Despesas com Pessoal   3476.34
